# %%
import pandas as pd
import numpy as np

# %% [markdown]
# mc1-reports-data.csv fields:
#
#     time: timestamp of incoming report/record, in the format YYYY-MM-DD hh:mm:ss
#
#     location: id of neighborhood where person reporting is feeling the shaking and/or seeing the damage
#
#     {shake_intensity, sewer_and_water, power, roads_and_bridges, medical, buildings}: reported categorical value of how violent the shaking was/how bad the damage was (0 - lowest, 10 - highest; missing data allowed)

# %%
df = pd.read_csv("mc1-reports-data.csv")
df.head()
# Out:
#                   time  sewer_and_water  power  roads_and_bridges  medical  \
# 0  2020-04-08 17:50:00             10.0    6.0               10.0      3.0
# 1  2020-04-09 13:50:00              2.0   10.0                0.0      8.0
# 2  2020-04-09 00:20:00              7.0   10.0               10.0      9.0
# 3  2020-04-08 17:25:00              1.0    1.0                2.0     10.0
# 4  2020-04-08 02:50:00              9.0    7.0                1.0      6.0
#
#    buildings  shake_intensity  location
# 0        8.0              NaN         1
# 1        4.0              0.0         1
# 2       10.0              0.0         1
# 3        7.0              NaN         1
# 4        9.0              NaN         1

# %%
len(df)
# Out:
# 83070

# %% [markdown]
# <h3>First I am trying to get an idea of data, min-max, count etc</h3>

# %%
df.describe()
# Out:
#        sewer_and_water         power  roads_and_bridges       medical  \
# count     82899.000000  83070.000000       83070.000000  35629.000000
# mean          5.649139      6.045371           5.743289      5.322687
# std           2.787791      2.851951           2.506399      2.527679
# min          -0.000000     -0.000000          -0.000000     -0.000000
# 25%           3.000000      4.000000           4.000000      4.000000
# 50%           6.000000      7.000000           6.000000      6.000000
# 75%           8.000000      8.000000           7.000000      7.000000
# max          10.000000     10.000000          10.000000     10.000000
#
#           buildings  shake_intensity      location
# count  82900.000000     70926.000000  83070.000000
# mean       4.744005         2.682641      8.978488
# std        2.256358         1.935366      5.123608
# min       -0.000000        -0.000000      1.000000
# 25%        3.000000         1.000000      4.000000
# 50%        5.000000         2.000000      8.000000
# 75%        6.000000         4.000000     14.000000
# max       10.000000         9.000000     19.000000

# %% [markdown]
# <h3> Now I noticed that medical, shake_intensity has unreported data</h3>
# Now, the reason shake intensity is so low is probably because a lot of places were far away from the epicenter of the shake, so people didn't feel the shake as much and didn't report anything. But it is very easy to notice any changes in power supply and road_bridge damage thus they are always reported.

# %%
df.isna().sum()
# Out:
# time                     0
# sewer_and_water        171
# power                    0
# roads_and_bridges        0
# medical              47441
# buildings              170
# shake_intensity      12144
# location                 0
# dtype: int64

# %% [markdown]
# <h5>Now, I thought that we should check which location has more reports</h5>

# %%
df.groupby('location')['time'].count()
# Out:
# location
# 1      1662
# 2      5390
# 3     13535
# 4      2919
# 5      1710
# 6      3160
# 7       173
# 8     13889
# 9      8796
# 10     2213
# 11     2844
# 12     3463
# 13     1226
# 14     6429
# 15     4729
# 16     3145
# 17     1727
# 18     4545
# 19     1515
# Name: time, dtype: int64

# %% [markdown]
# <h5>Location 8 and 3 have a very high amount of reports and they both are located near the border so that might be something we can look into. Location 7 is a forest so it makes sense that the number of reports from it is low.</h5>
# To see the locations, check out the map given in file "About our city" in the neighborhood section.

# %% [markdown]
# <h5>We can seprate all the different columns and create graphs (bar graph or tree map etc) for each seprately. We'll also create a combined graph but this way we'll have more number of visualizations</h5>

# %%
df_sewer_and_water = df[['time','sewer_and_water','location']]
df_power= df[['time','power','location']]
df_roads_and_bridges = df[['time','roads_and_bridges','location']]
df_medical = df[['time','medical','location']]
df_buildings = df[['time','buildings','location']]
df_shake_intensity = df[['time','shake_intensity','location']]

# %%
df_power.head()
# Out:
#                   time  power  location
# 0  2020-04-08 17:50:00    6.0         1
# 1  2020-04-09 13:50:00   10.0         1
# 2  2020-04-09 00:20:00   10.0         1
# 3  2020-04-08 17:25:00    1.0         1
# 4  2020-04-08 02:50:00    7.0         1

# %% [markdown]
# <h4>Before we start working on individual things, I think let's finalize aggregate stuff first</h4>
# <h5>So I am thinking we can create a new aggregate dataframe with average report of a day for a location and use that to display the aggregate day's result</h5>

# %%
df_aggregate=df
df_aggregate.head()
# Out:
#                   time  sewer_and_water  power  roads_and_bridges  medical  \
# 0  2020-04-08 17:50:00             10.0    6.0               10.0      3.0
# 1  2020-04-09 13:50:00              2.0   10.0                0.0      8.0
# 2  2020-04-09 00:20:00              7.0   10.0               10.0      9.0
# 3  2020-04-08 17:25:00              1.0    1.0                2.0     10.0
# 4  2020-04-08 02:50:00              9.0    7.0                1.0      6.0
#
#    buildings  shake_intensity  location
# 0        8.0              NaN         1
# 1        4.0              0.0         1
# 2       10.0              0.0         1
# 3        7.0              NaN         1
# 4        9.0              NaN         1

# %%
df_temp = df
df_temp = df_temp.fillna(0.0)
df_temp[['sewer_and_water','power','roads_and_bridges','medical','buildings','shake_intensity']].apply(abs)
df_temp[['date','time_of_day']] = df_temp.time.str.split(expand=True)
df_temp['hour'] = pd.to_datetime(df_temp['time_of_day'], format='%H:%M:%S').dt.hour

df_temp[['sewer_and_water_mean','power_mean','roads_and_bridges_mean','medical_mean','buildings_mean','shake_intensity_mean']] = df_temp.groupby(['location','hour','date'])[['sewer_and_water','power','roads_and_bridges','medical','buildings','shake_intensity']].transform('mean')
df_temp = df_temp.drop(['time','time_of_day','index','sewer_and_water','power','roads_and_bridges','medical','buildings','shake_intensity'],axis=1)
df_temp=df_temp.drop_duplicates(subset=['date','hour','location']).reset_index()
df_temp.sort_values(['hour', 'location'], ascending=[True, True],inplace=True)
df_temp = df_temp.drop('index',axis=1)
df_temp.head(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [10], line 8
#       5 df_temp['hour'] = pd.to_datetime(df_temp['time_of_day'], format='%H:%M:%S').dt.hour
#       7 df_temp[['sewer_and_water_mean','power_mean','roads_and_bridges_mean','medical_mean','buildings_mean','shake_intensity_mean']] = df_temp.groupby(['location','hour','date'])[['sewer_and_water','power','roads_and_bridges','medical','buildings','shake_intensity']].transform('mean')
# ----> 8 df_temp = df_temp.drop(['time','time_of_day','index','sewer_and_water','power','roads_and_bridges','medical','buildings','shake_intensity'],axis=1)
#       9 df_temp=df_temp.drop_duplicates(subset=['date','hour','location']).reset_index()
#      10 df_temp.sort_values(['hour', 'location'], ascending=[True, True],inplace=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4809 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4810 def drop(
#    4811     self,
#    (...)
#    4818     errors: str = "raise",
#    4819 ):
#    4820     """
#    4821     Drop specified labels from rows or columns.
#    4822
#    (...)
#    4955             weight  1.0     0.8
#    4956     """
# -> 4957     return super().drop(
#    4958         labels=labels,
#    4959         axis=axis,
#    4960         index=index,
#    4961         columns=columns,
#    4962         level=level,
#    4963         inplace=inplace,
#    4964         errors=errors,
#    4965     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6661, in Index.drop(self, labels, errors)
#    6659 if mask.any():
#    6660     if errors != "ignore":
# -> 6661         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662     indexer = indexer[~mask]
#    6663 return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
df_temp.to_csv('data_with_time.csv')

# %%
df_shake_intensity[['date','time_of_day']] = df_shake_intensity.time.str.split(expand=True)
df_shake_intensity['hour'] = pd.to_datetime(df_shake_intensity['time_of_day'], format='%H:%M:%S').dt.hour
df_shake_intensity
# Out:
# /var/folders/_2/q6ygxk0j3rv7n_4_k8l_18gc0000gn/T/ipykernel_3334/1840806634.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shake_intensity[['date','time_of_day']] = df_shake_intensity.time.str.split(expand=True)
# /var/folders/_2/q6ygxk0j3rv7n_4_k8l_18gc0000gn/T/ipykernel_3334/1840806634.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shake_intensity[['date','time_of_day']] = df_shake_intensity.time.str.split(expand=True)
# /var/folders/_2/q6ygxk0j3rv7n_4_k8l_18gc0000gn/T/ipykernel_3334/1840806634.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shake_intensity['hour'] = pd.to_datetime(df_shake_intensity['time_of_day'], format='%H:%M:%S').dt.hour
#                       time  shake_intensity  location        date time_of_day  \
# 0      2020-04-08 17:50:00              NaN         1  2020-04-08    17:50:00
# 1      2020-04-09 13:50:00              0.0         1  2020-04-09    13:50:00
# 2      2020-04-09 00:20:00              0.0         1  2020-04-09    00:20:00
# 3      2020-04-08 17:25:00              NaN         1  2020-04-08    17:25:00
# 4      2020-04-08 02:50:00              NaN         1  2020-04-08    02:50:00
# ...                    ...              ...       ...         ...         ...
# 83065  2020-04-10 02:30:00              2.0         8  2020-04-10    02:30:00
# 83066  2020-04-10 02:30:00              1.0         8  2020-04-10    02:30:00
# 83067  2020-04-09 16:45:00              1.0         8  2020-04-09    16:45:00
# 83068  2020-04-09 16:55:00              0.0         8  2020-04-09    16:55:00
# 83069  2020-04-10 02:30:00             -0.0         8  2020-04-10    02:30:00
#
#        hour
# 0        17
# 1        13
# 2         0
# 3        17
# 4         2
# ...     ...
# 83065     2
# 83066     2
# 83067    16
# 83068    16
# 83069     2
#
# [83070 rows x 6 columns]

# %%
df_temp = df
df_temp = df_temp.fillna(0.0)
df_temp[['date','time_of_day']] = df_temp.time.str.split(expand=True)
df_temp = df_temp.drop(['time'],axis=1)
df_temp.head()
# Out:
#    sewer_and_water  power  roads_and_bridges  medical  buildings  \
# 0             10.0    6.0               10.0      3.0        8.0
# 1              2.0   10.0                0.0      8.0        4.0
# 2              7.0   10.0               10.0      9.0       10.0
# 3              1.0    1.0                2.0     10.0        7.0
# 4              9.0    7.0                1.0      6.0        9.0
#
#    shake_intensity  location        date time_of_day
# 0              0.0         1  2020-04-08    17:50:00
# 1              0.0         1  2020-04-09    13:50:00
# 2              0.0         1  2020-04-09    00:20:00
# 3              0.0         1  2020-04-08    17:25:00
# 4              0.0         1  2020-04-08    02:50:00

# %%
df_temp.to_csv("data_with_time.csv")

# %%
df_aggregate[['date','time_of_day']] = df_aggregate.time.str.split(expand=True)
df_aggregate = df_aggregate.drop(['time','time_of_day'],axis=1)
df_aggregate.head()
# Out:
#    sewer_and_water  power  roads_and_bridges  medical  buildings  \
# 0             10.0    6.0               10.0      3.0        8.0
# 1              2.0   10.0                0.0      8.0        4.0
# 2              7.0   10.0               10.0      9.0       10.0
# 3              1.0    1.0                2.0     10.0        7.0
# 4              9.0    7.0                1.0      6.0        9.0
#
#    shake_intensity  location        date
# 0              NaN         1  2020-04-08
# 1              0.0         1  2020-04-09
# 2              0.0         1  2020-04-09
# 3              NaN         1  2020-04-08
# 4              NaN         1  2020-04-08

# %% [markdown]
# So, I am removing NAN for now, cause if they didn't report anything then they probably didn't feel anything

# %%
df_aggregate = df_aggregate.fillna(0.0)
df_aggregate.head()
# Out:
#    sewer_and_water  power  roads_and_bridges  medical  buildings  \
# 0             10.0    6.0               10.0      3.0        8.0
# 1              2.0   10.0                0.0      8.0        4.0
# 2              7.0   10.0               10.0      9.0       10.0
# 3              1.0    1.0                2.0     10.0        7.0
# 4              9.0    7.0                1.0      6.0        9.0
#
#    shake_intensity  location        date
# 0              0.0         1  2020-04-08
# 1              0.0         1  2020-04-09
# 2              0.0         1  2020-04-09
# 3              0.0         1  2020-04-08
# 4              0.0         1  2020-04-08

# %%
df_aggregate_mean = df_aggregate
df_aggregate_mean[['sewer_and_water_mean','power_mean','roads_and_bridges_mean','medical_mean','buildings_mean','shake_intensity_mean']] = df_aggregate.groupby(['location','date'])[['sewer_and_water','power','roads_and_bridges','medical','buildings','shake_intensity']].transform('mean')
df_aggregate_mean = df_aggregate_mean.drop(['sewer_and_water','power','roads_and_bridges','medical','buildings','shake_intensity'],axis=1)
df_aggregate_mean = df_aggregate_mean.drop_duplicates(subset=['date','location']).reset_index()
df_aggregate_mean = df_aggregate_mean.drop('index',axis=1)
df_aggregate_mean.head(20)
# Out:
#     location        date  sewer_and_water_mean  power_mean  \
# 0          1  2020-04-08              5.015702    5.039669
# 1          1  2020-04-09              3.323383    3.273632
# 2          1  2020-04-10              4.608696    5.086957
# 3          1  2020-04-07              5.116883    5.506494
# 4          1  2020-04-06              4.085714    3.609524
# 5          2  2020-04-10              5.348018    5.162996
# 6          2  2020-04-09              3.474882    5.037915
# 7          2  2020-04-06              3.158974    3.010256
# 8          2  2020-04-08              3.153140    4.108689
# 9          2  2020-04-07              5.589520    5.497817
# 10         2  2020-04-11              6.000000    1.500000
# 11         3  2020-04-07              5.573770    5.404372
# 12         3  2020-04-06              3.832215    3.731544
# 13         3  2020-04-10              9.552888    9.574894
# 14         3  2020-04-09              6.885129    8.641604
# 15         3  2020-04-08              6.047115    7.973293
# 16         4  2020-04-07              5.705882    5.941176
# 17         4  2020-04-09              6.951426    5.062302
# 18         4  2020-04-08              4.871259    3.872953
# 19         4  2020-04-06              2.236842    1.710526
#
#     roads_and_bridges_mean  medical_mean  buildings_mean  shake_intensity_mean
# 0                 5.019008      5.033884        5.113223              0.406612
# 1                 4.228856      4.099502        3.407960              0.129353
# 2                 4.869565      5.884058        5.753623              0.086957
# 3                 5.233766      6.480519        5.571429              0.129870
# 4                 4.076190      4.266667        4.323810              0.133333
# 5                 5.013216      0.026432        6.189427              0.074890
# 6                 4.318483      0.090995        1.898578              0.837915
# 7                 3.307692      0.092308        3.648718              0.148718
# 8                 5.058503      0.088902        1.285632              1.677086
# 9                 4.934498      0.139738        5.423581              0.087336
# 10                5.000000      0.000000        4.500000              0.000000
# 11                5.491803      5.918033        5.338798              0.125683
# 12                3.889262      3.384228        3.728188              0.451342
# 13                9.556889      6.891473        6.899975              4.772443
# 14                6.865497      7.719298        5.860902              4.096491
# 15                6.033510      7.022928        5.059713              5.829176
# 16                4.803922      0.000000        4.921569              0.078431
# 17                4.976769      0.090813        4.989440              4.796199
# 18                3.884246      0.096556        2.952005              4.412196
# 19                2.245614      0.166667        3.149123              0.684211

# %% [markdown]
# Removing the date 2020-04-11 as not all locations reported that day, the better thing to do would be to add 2020-04-11 with value of 0.0 to all the locations without that date, but this is easier for now.

# %%
df_aggregate_mean = df_aggregate_mean[df_aggregate_mean.date != "2020-04-11"]
df_aggregate_mean.head(20)
# Out:
#     location        date  sewer_and_water_mean  power_mean  \
# 0          1  2020-04-08              5.015702    5.039669
# 1          1  2020-04-09              3.323383    3.273632
# 2          1  2020-04-10              4.608696    5.086957
# 3          1  2020-04-07              5.116883    5.506494
# 4          1  2020-04-06              4.085714    3.609524
# 5          2  2020-04-10              5.348018    5.162996
# 6          2  2020-04-09              3.474882    5.037915
# 7          2  2020-04-06              3.158974    3.010256
# 8          2  2020-04-08              3.153140    4.108689
# 9          2  2020-04-07              5.589520    5.497817
# 11         3  2020-04-07              5.573770    5.404372
# 12         3  2020-04-06              3.832215    3.731544
# 13         3  2020-04-10              9.552888    9.574894
# 14         3  2020-04-09              6.885129    8.641604
# 15         3  2020-04-08              6.047115    7.973293
# 16         4  2020-04-07              5.705882    5.941176
# 17         4  2020-04-09              6.951426    5.062302
# 18         4  2020-04-08              4.871259    3.872953
# 19         4  2020-04-06              2.236842    1.710526
# 20         4  2020-04-10              5.750000    4.972222
#
#     roads_and_bridges_mean  medical_mean  buildings_mean  shake_intensity_mean
# 0                 5.019008      5.033884        5.113223              0.406612
# 1                 4.228856      4.099502        3.407960              0.129353
# 2                 4.869565      5.884058        5.753623              0.086957
# 3                 5.233766      6.480519        5.571429              0.129870
# 4                 4.076190      4.266667        4.323810              0.133333
# 5                 5.013216      0.026432        6.189427              0.074890
# 6                 4.318483      0.090995        1.898578              0.837915
# 7                 3.307692      0.092308        3.648718              0.148718
# 8                 5.058503      0.088902        1.285632              1.677086
# 9                 4.934498      0.139738        5.423581              0.087336
# 11                5.491803      5.918033        5.338798              0.125683
# 12                3.889262      3.384228        3.728188              0.451342
# 13                9.556889      6.891473        6.899975              4.772443
# 14                6.865497      7.719298        5.860902              4.096491
# 15                6.033510      7.022928        5.059713              5.829176
# 16                4.803922      0.000000        4.921569              0.078431
# 17                4.976769      0.090813        4.989440              4.796199
# 18                3.884246      0.096556        2.952005              4.412196
# 19                2.245614      0.166667        3.149123              0.684211
# 20                5.750000      0.166667        5.944444              0.222222

# %%
df_aggregate_mean.to_csv('df_aggregate_mean.csv')

# %% [markdown]
# We can create a visualization for just locations, like during the whole saga what was the average response for each location.

# %%
df_aggregate_mean_without_date = df_aggregate
df_aggregate_mean_without_date[['sewer_and_water_mean','power_mean','roads_and_bridges_mean','medical_mean','buildings_mean','shake_intensity_mean']] = df_aggregate.groupby(['location'])[['sewer_and_water','power','roads_and_bridges','medical','buildings','shake_intensity']].transform('mean')
df_aggregate_mean_without_date = df_aggregate_mean_without_date.drop(['date','sewer_and_water','power','roads_and_bridges','medical','buildings','shake_intensity'],axis=1)
df_aggregate_mean_without_date = df_aggregate_mean_without_date.drop_duplicates(subset=['location']).reset_index()
df_aggregate_mean_without_date = df_aggregate_mean_without_date.drop('index',axis=1)
df_aggregate_mean_without_date
# Out:
#     location  sewer_and_water_mean  power_mean  roads_and_bridges_mean  \
# 0          1              4.740072    4.759326                4.867629
# 1          2              3.413544    4.313544                4.779777
# 2          3              7.275434    8.461396                7.267085
# 3          4              5.468654    4.224049                4.213772
# 4          5              4.205263    5.065497                4.083626
# 5          6              2.937975    3.062975                3.318987
# 6          7              0.098266    7.838150                5.919075
# 7          8              7.499748    7.457772                7.658291
# 8          9              7.456003    5.726353                6.591291
# 9         10              5.676909    7.618165                5.950294
# 10        11              6.289030    7.695148                4.981716
# 11        12              3.182789    5.586197                4.039850
# 12        13              3.889886    3.243883                4.159054
# 13        14              6.125836    6.256494                6.272360
# 14        15              3.534574    3.141256                3.577078
# 15        16              5.182830    3.627345                4.171383
# 16        17              1.910249    5.891720                5.874349
# 17        18              3.356436    6.025963                4.056986
# 18        19              2.748515    2.912211                2.887789
#
#     medical_mean  buildings_mean  shake_intensity_mean
# 0       4.974729        4.904934              0.329723
# 1       0.089054        1.960111              1.266605
# 2       7.055264        5.831991              4.590100
# 3       0.096608        3.692018              4.263789
# 4       2.110526        3.494737              0.519298
# 5       3.306013        3.516139              0.766139
# 6       0.034682        0.098266              4.421965
# 7       0.087551        5.781986              1.527252
# 8       5.184970        6.168486              0.973511
# 9       0.075915        6.351559              1.372797
# 10      3.844233        4.963783              2.386428
# 11      0.079988        3.140341              4.085186
# 12      0.068515        4.041599              0.955954
# 13      0.062685        4.724063              3.214652
# 14      0.087756        3.080355              1.707972
# 15      3.614944        3.349444              0.358029
# 16      0.090330        3.294152              1.449913
# 17      0.069087        4.980858              3.242464
# 18      0.075908        3.549835              1.463366

# %%
def creating_json(df):
   entries = []
   values = set(df.iloc[:, 0])
   for v in range(len(df)):
      entries.append({
         'Name':df.iloc[v][0],
         'Children':[{'Name':'sewer_and_water_mean','value':df.iloc[v][1]},
                     {'Name':'power_mean','value':df.iloc[v][2]},
                     {'Name':'roads_and_bridges_mean','value':df.iloc[v][3]},
                     {'Name':'medical_mean','value':df.iloc[v][4]},
                     {'Name':'buildings_mean','value':df.iloc[v][5]},
                     {'Name':'shake_intensity_mean','value':df.iloc[v][6]}]
      })
      #print(df.iloc[18][1])
   return entries

# %%
mydict = {"Name": "Himark",
          "Children": creating_json(df_aggregate_mean_without_date)}
mydict['Children']
# Out:
# [{'Name': 1.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 4.740072202166065},
#    {'Name': 'power_mean', 'value': 4.759326113116727},
#    {'Name': 'roads_and_bridges_mean', 'value': 4.8676293622142},
#    {'Name': 'medical_mean', 'value': 4.974729241877256},
#    {'Name': 'buildings_mean', 'value': 4.904933814681107},
#    {'Name': 'shake_intensity_mean', 'value': 0.3297232250300842}]},
#  {'Name': 2.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 3.413543599257885},
#    {'Name': 'power_mean', 'value': 4.313543599257885},
#    {'Name': 'roads_and_bridges_mean', 'value': 4.779777365491651},
#    {'Name': 'medical_mean', 'value': 0.08905380333951762},
#    {'Name': 'buildings_mean', 'value': 1.9601113172541744},
#    {'Name': 'shake_intensity_mean', 'value': 1.2666048237476808}]},
#  {'Name': 3.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 7.275434059844847},
#    {'Name': 'power_mean', 'value': 8.461396379756188},
#    {'Name': 'roads_and_bridges_mean', 'value': 7.267085334318434},
#    {'Name': 'medical_mean', 'value': 7.0552641300332475},
#    {'Name': 'buildings_mean', 'value': 5.8319911340967865},
#    {'Name': 'shake_intensity_mean', 'value': 4.590099741411156}]},
#  {'Name': 4.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 5.468653648509764},
#    {'Name': 'power_mean', 'value': 4.224049331963001},
#    {'Name': 'roads_and_bridges_mean', 'value': 4.213771839671121},
#    {'Name': 'medical_mean', 'value': 0.09660842754367935},
#    {'Name': 'buildings_mean', 'value': 3.6920178143199727},
#    {'Name': 'shake_intensity_mean', 'value': 4.26378896882494}]},
#  {'Name': 5.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 4.205263157894737},
#    {'Name': 'power_mean', 'value': 5.065497076023392},
#    {'Name': 'roads_and_bridges_mean', 'value': 4.083625730994152},
#    {'Name': 'medical_mean', 'value': 2.110526315789474},
#    {'Name': 'buildings_mean', 'value': 3.4947368421052634},
#    {'Name': 'shake_intensity_mean', 'value': 0.519298245614035}]},
#  {'Name': 6.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 2.937974683544304},
#    {'Name': 'power_mean', 'value': 3.062974683544304},
#    {'Name': 'roads_and_bridges_mean', 'value': 3.318987341772152},
#    {'Name': 'medical_mean', 'value': 3.306012658227848},
#    {'Name': 'buildings_mean', 'value': 3.516139240506329},
#    {'Name': 'shake_intensity_mean', 'value': 0.7661392405063291}]},
#  {'Name': 7.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 0.09826589595375723},
#    {'Name': 'power_mean', 'value': 7.838150289017341},
#    {'Name': 'roads_and_bridges_mean', 'value': 5.91907514450867},
#    {'Name': 'medical_mean', 'value': 0.03468208092485549},
#    {'Name': 'buildings_mean', 'value': 0.09826589595375723},
#    {'Name': 'shake_intensity_mean', 'value': 4.421965317919075}]},
#  {'Name': 8.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 7.499748002015984},
#    {'Name': 'power_mean', 'value': 7.4577723378212974},
#    {'Name': 'roads_and_bridges_mean', 'value': 7.65829073367413},
#    {'Name': 'medical_mean', 'value': 0.08755129958960328},
#    {'Name': 'buildings_mean', 'value': 5.781985744114047},
#    {'Name': 'shake_intensity_mean', 'value': 1.527251781985744}]},
#  {'Name': 9.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 7.456002728512961},
#    {'Name': 'power_mean', 'value': 5.726352887676216},
#    {'Name': 'roads_and_bridges_mean', 'value': 6.591291496134606},
#    {'Name': 'medical_mean', 'value': 5.184970441109595},
#    {'Name': 'buildings_mean', 'value': 6.1684856753069575},
#    {'Name': 'shake_intensity_mean', 'value': 0.9735106866757617}]},
#  {'Name': 10.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 5.676909173068233},
#    {'Name': 'power_mean', 'value': 7.6181653863533665},
#    {'Name': 'roads_and_bridges_mean', 'value': 5.950293718933574},
#    {'Name': 'medical_mean', 'value': 0.07591504744690465},
#    {'Name': 'buildings_mean', 'value': 6.351558969724356},
#    {'Name': 'shake_intensity_mean', 'value': 1.3727971079981924}]},
#  {'Name': 11.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 6.289029535864979},
#    {'Name': 'power_mean', 'value': 7.6951476793248945},
#    {'Name': 'roads_and_bridges_mean', 'value': 4.981715893108298},
#    {'Name': 'medical_mean', 'value': 3.8442334739803092},
#    {'Name': 'buildings_mean', 'value': 4.963783403656821},
#    {'Name': 'shake_intensity_mean', 'value': 2.386427566807314}]},
#  {'Name': 12.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 3.182789488882472},
#    {'Name': 'power_mean', 'value': 5.58619693907017},
#    {'Name': 'roads_and_bridges_mean', 'value': 4.039849841178169},
#    {'Name': 'medical_mean', 'value': 0.07998844932139763},
#    {'Name': 'buildings_mean', 'value': 3.14034074501877},
#    {'Name': 'shake_intensity_mean', 'value': 4.085186254692463}]},
#  {'Name': 13.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 3.8898858075040783},
#    {'Name': 'power_mean', 'value': 3.2438825448613375},
#    {'Name': 'roads_and_bridges_mean', 'value': 4.1590538336052205},
#    {'Name': 'medical_mean', 'value': 0.06851549755301795},
#    {'Name': 'buildings_mean', 'value': 4.041598694942904},
#    {'Name': 'shake_intensity_mean', 'value': 0.9559543230016313}]},
#  {'Name': 14.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 6.125836055374086},
#    {'Name': 'power_mean', 'value': 6.256494011510344},
#    {'Name': 'roads_and_bridges_mean', 'value': 6.2723596204697465},
#    {'Name': 'medical_mean', 'value': 0.06268470990822834},
#    {'Name': 'buildings_mean', 'value': 4.724062840255094},
#    {'Name': 'shake_intensity_mean', 'value': 3.214652356509566}]},
#  {'Name': 15.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 3.534573905688306},
#    {'Name': 'power_mean', 'value': 3.14125607950941},
#    {'Name': 'roads_and_bridges_mean', 'value': 3.5770776062592513},
#    {'Name': 'medical_mean', 'value': 0.08775639670120533},
#    {'Name': 'buildings_mean', 'value': 3.0803552548107422},
#    {'Name': 'shake_intensity_mean', 'value': 1.7079720871220132}]},
#  {'Name': 16.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 5.1828298887122415},
#    {'Name': 'power_mean', 'value': 3.6273449920508742},
#    {'Name': 'roads_and_bridges_mean', 'value': 4.171383147853736},
#    {'Name': 'medical_mean', 'value': 3.6149443561208265},
#    {'Name': 'buildings_mean', 'value': 3.349443561208267},
#    {'Name': 'shake_intensity_mean', 'value': 0.35802861685214626}]},
#  {'Name': 17.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 1.9102489866821077},
#    {'Name': 'power_mean', 'value': 5.89171974522293},
#    {'Name': 'roads_and_bridges_mean', 'value': 5.874348581354951},
#    {'Name': 'medical_mean', 'value': 0.0903300521134916},
#    {'Name': 'buildings_mean', 'value': 3.294151708164447},
#    {'Name': 'shake_intensity_mean', 'value': 1.44991314418066}]},
#  {'Name': 18.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 3.3564356435643563},
#    {'Name': 'power_mean', 'value': 6.025962596259626},
#    {'Name': 'roads_and_bridges_mean', 'value': 4.056985698569857},
#    {'Name': 'medical_mean', 'value': 0.06908690869086909},
#    {'Name': 'buildings_mean', 'value': 4.980858085808581},
#    {'Name': 'shake_intensity_mean', 'value': 3.2424642464246425}]},
#  {'Name': 19.0,
#   'Children': [{'Name': 'sewer_and_water_mean', 'value': 2.7485148514851487},
#    {'Name': 'power_mean', 'value': 2.9122112211221123},
#    {'Name': 'roads_and_bridges_mean', 'value': 2.887788778877888},
#    {'Name': 'medical_mean', 'value': 0.07590759075907591},
#    {'Name': 'buildings_mean', 'value': 3.54983498349835},
#    {'Name': 'shake_intensity_mean', 'value': 1.4633663366336633}]}]

# %%
import json
with open("df_aggregate_mean_without_date.json", "w") as outfile:
    json.dump(mydict, outfile)

# %%
df_power_plant = df[df['location']==4]
df_power_plant = df_power_plant.fillna(0.0)
df_power_plant[['date','time_of_day']] = df_power_plant.time.str.split(expand=True)
df_power_plant = df_power_plant.drop('time',axis=1)
df_power_plant
# Out:
#        sewer_and_water  power  roads_and_bridges  medical  buildings  \
# 2347               4.0    0.0                8.0      0.0        7.0
# 2348               5.0    8.0                3.0      0.0        5.0
# 2349               9.0   10.0                0.0      0.0        2.0
# 2350               5.0   10.0                0.0      0.0        9.0
# 2351               3.0    2.0                6.0      0.0        5.0
# ...                ...    ...                ...      ...        ...
# 69621              7.0    6.0                5.0      0.0        7.0
# 69622              8.0    5.0                6.0      0.0        4.0
# 69623              7.0    5.0                5.0      0.0        5.0
# 69624              6.0    6.0                6.0      0.0        4.0
# 69625              7.0    5.0                5.0      0.0        6.0
#
#        shake_intensity  location        date time_of_day
# 2347               0.0         4  2020-04-07    20:40:00
# 2348               0.0         4  2020-04-09    14:05:00
# 2349               0.0         4  2020-04-09    12:05:00
# 2350               1.0         4  2020-04-08    16:35:00
# 2351               0.0         4  2020-04-08    16:55:00
# ...                ...       ...         ...         ...
# 69621              5.0         4  2020-04-09    15:45:00
# 69622              5.0         4  2020-04-09    18:35:00
# 69623              6.0         4  2020-04-09    15:45:00
# 69624              6.0         4  2020-04-09    17:05:00
# 69625              6.0         4  2020-04-09    16:05:00
#
# [2919 rows x 9 columns]

# %%
df_power_plant.to_csv("power_plant_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 df_power_plant.to_csv("power_plant_data.csv")
#
# NameError: name 'df_power_plant' is not defined

# %%
df_line = df
df_line = df_line.fillna(0.0)
df_line[['date','time_of_day']] = df_line.time.str.split(expand=True)
df[['sewer_and_water','power','roads_and_bridges','medical','buildings','shake_intensity']] = df_line[['sewer_and_water','power','roads_and_bridges','medical','buildings','shake_intensity']].abs

df_line
# Out:
#                       time  sewer_and_water  power  roads_and_bridges  \
# 0      2020-04-08 17:50:00             10.0    6.0               10.0
# 1      2020-04-09 13:50:00              2.0   10.0                0.0
# 2      2020-04-09 00:20:00              7.0   10.0               10.0
# 3      2020-04-08 17:25:00              1.0    1.0                2.0
# 4      2020-04-08 02:50:00              9.0    7.0                1.0
# ...                    ...              ...    ...                ...
# 83065  2020-04-10 02:30:00              9.0   10.0               10.0
# 83066  2020-04-10 02:30:00              8.0   10.0               10.0
# 83067  2020-04-09 16:45:00             10.0    9.0               10.0
# 83068  2020-04-09 16:55:00              8.0    8.0                9.0
# 83069  2020-04-10 02:30:00              9.0   10.0               10.0
#
#        medical  buildings  shake_intensity  location        date time_of_day
# 0          3.0        8.0              0.0         1  2020-04-08    17:50:00
# 1          8.0        4.0              0.0         1  2020-04-09    13:50:00
# 2          9.0       10.0              0.0         1  2020-04-09    00:20:00
# 3         10.0        7.0              0.0         1  2020-04-08    17:25:00
# 4          6.0        9.0              0.0         1  2020-04-08    02:50:00
# ...        ...        ...              ...       ...         ...         ...
# 83065      0.0        7.0              2.0         8  2020-04-10    02:30:00
# 83066      0.0        7.0              1.0         8  2020-04-10    02:30:00
# 83067      0.0        8.0              1.0         8  2020-04-09    16:45:00
# 83068      0.0        7.0              0.0         8  2020-04-09    16:55:00
# 83069      0.0        6.0             -0.0         8  2020-04-10    02:30:00
#
# [83070 rows x 10 columns]

# %%
df_line.to_csv('df_line.csv')
